# %%
import pandas as pd

# %%
df=pd.read_csv('defi_dataset.csv')

# %%
df
# Out:
#                Name          Category     Chain         Type   Token
# 0     Yearn Finance  Yield Aggregator  ethereum  Tokens(USD)    USDT  \
# 1     Yearn Finance  Yield Aggregator     Total  Tokens(USD)    USDT
# 2     Yearn Finance  Yield Aggregator    fantom  Tokens(USD)    USDT
# 3     Yearn Finance  Yield Aggregator  ethereum       Tokens    USDT
# 4     Yearn Finance  Yield Aggregator     Total       Tokens    USDT
# ...             ...               ...       ...          ...     ...
# 1991     BakerySwap             Dexes     Total  Tokens(USD)  GRIMEX
# 1992     BakerySwap             Dexes     Total  Tokens(USD)     MDG
# 1993     BakerySwap             Dexes     Total  Tokens(USD)    WBNB
# 1994     BakerySwap             Dexes     Total  Tokens(USD)     BOG
# 1995     BakerySwap             Dexes     Total  Tokens(USD)   TOKAU
#
#         14/09/2021    15/09/2021    16/09/2021    17/09/2021    18/09/2021
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Category     0
# Chain        0
# Type         0
# Token        0
#             ..
# 2/12/2022    0
# 3/12/2022    0
# 4/12/2022    0
# 5/12/2022    0
# 6/12/2022    0
# Length: 402, dtype: int64

# %%
df2=df.iloc[0:1996,4:402]

# %%
df[df['Chain']=='bsc']
# Out:
#                Name Category Chain         Type  Token    14/09/2021
# 44         Coinwind    Yield   bsc       Tokens   CAKE  8.512811e+04  \
# 45         Coinwind    Yield   bsc       Tokens    EOS  3.310535e+04
# 46         Coinwind    Yield   bsc       Tokens   DOGE  5.441158e+05
# 89    Alita Finance    Dexes   bsc       Tokens   USDT  2.132859e+07
# 90    Alita Finance    Dexes   bsc       Tokens   WBNB  7.768180e+04
# ...             ...      ...   ...          ...    ...           ...
# 1878     BakerySwap    Dexes   bsc  Tokens(USD)  HONEY  1.267113e+01
# 1879     BakerySwap    Dexes   bsc  Tokens(USD)   BMON  6.112513e-02
# 1880     BakerySwap    Dexes   bsc  Tokens(USD)  GUARD  7.073334e+01
# 1881     BakerySwap    Dexes   bsc  Tokens(USD)   AIRT  2.912490e-04
# 1882     BakerySwap    Dexes   bsc  Tokens(USD)   DOGO  3.230000e-17
#
#         15/09/2021    16/09/2021    17/09/2021    18/09/2021  ...
# 44    8.499807e+04  8.152241e+04  7.975532e+04  7.783010e+04  ...  \
# ...

# %%
df['Chain'].value_counts()
# Out:
# Chain
# Total                978
# ethereum             213
# bsc                  192
# borrowed             173
# polygon              158
# ethereum-borrowed    155
# staking               26
# avalanche             18
# bsc-pool2             18
# ethereum-staking      18
# pool2                 15
# ethereum-pool2        14
# bsc-staking            7
# polygon-staking        4
# polygon-pool2          3
# arbitrum               2
# fantom                 2
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          14/09/2021    15/09/2021    16/09/2021    17/09/2021    18/09/2021
# count  1.996000e+03  1.996000e+03  1.996000e+03  1.996000e+03  1.996000e+03  \
# mean   6.175601e+10  6.266485e+10  6.135451e+10  6.126864e+10  6.035073e+10
# std    2.012404e+12  2.217335e+12  2.212060e+12  2.211816e+12  2.209888e+12
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6
# %%
total_market_value_locked=df2.groupby('Token').sum()
total_market_value_locked.to_csv('total_market_value_locked.csv')

# %% [markdown]
# ## How manny token on what platform for.eg:- Dex's

# %%
df.groupby('Name').count()
# Out:
#                      Category  Chain  Type  Token  14/09/2021  15/09/2021
# Name
# AAVE V1                   171    171   171    171         171         171  \
# Alita Finance              11     11    11     11          11          11
# BakerySwap                277    277   277    277         277         277
# Balancer                    8      8     8      8           8           8
# Bancor V2.1               305    305   305    305         305         305
# CREAM Finance              52     52    52     52          52          52
# Coinwind                   12     12    12     12          12          12
# Cycle Finance              32     32    32     32          32          32
# Defi Yield Protocol         1      1     1      1           1           1
# Dfyn Network              242    242   242    242         242         242
# Hegic                       6      6     6      6           6           6
# Kogefarm                   23     23    23     23          23          23
# ...

# %%
df['Name'].value_counts().to_frame()
# Out:
#                      count
# Name
# MANTRA DAO             525
# Bancor V2.1            305
# BakerySwap             277
# Dfyn Network           242
# AAVE V1                171
# Sushi Kashi            121
# KyberSwap              112
# ShibaSwap               68
# CREAM Finance           52
# Cycle Finance           32
# Kogefarm                23
# Loopring                16
# Coinwind                12
# Alita Finance           11
# Balancer                 8
# Zabu Finance             7
# Hegic                    6
# Yearn Finance            6
# Defi Yield Protocol      1
# Orion Protocol           1

# %%
larger_dex_token=df['Name'].value_counts().to_frame()
larger_dex_token.to_csv('larger_dex_token.csv')

# %%
df.groupby('Token').count()
# Out:
#        Name  Category  Chain  Type  14/09/2021  15/09/2021  16/09/2021
# Token
# 1INCH    17        17     17    17          17          17          17  \
# AAVE     29        29     29    29          29          29          29
# ABX       2         2      2     2           2           2           2
# ACPT      1         1      1     1           1           1           1
# ADA       4         4      4     4           4           4           4
# ...     ...       ...    ...   ...         ...         ...         ...
# ZCN       2         2      2     2           2           2           2
# ZEE       5         5      5     5           5           5           5
# ZIPT      2         2      2     2           2           2           2
# ZLOT      8         8      8     8           8           8           8
# ZRX      20        20     20    20          20          20          20
#
#        17/09/2021  18/09/2021  19/09/2021  ...  27/11/2022  28/11/2022
# ...

# %%
df['Token'].value_counts().to_frame()
# Out:
#            count
# Token
# USDT          52
# WETH          40
# USDC          38
# DAI           38
# LINK          35
# ...          ...
# REPV2          1
# PAXG           1
# FTX TOKEN      1
# FTM            1
# DOGO           1
#
# [492 rows x 1 columns]

# %%
Higher_token_supply=df['Token'].value_counts().to_frame()
Higher_token_supply.to_csv('Higher_token_supply.csv')

# %% [markdown]
# ## Each token count

# %%
df3=df2.groupby('Token').value_counts().to_frame()

# %%
df3.to_csv('Multiple_token.csv')

# %%
df3_A=pd.read_csv('Multiple_token.csv')
df3_A
# Out:
#       Token    14/09/2021    15/09/2021    16/09/2021    17/09/2021
# 0     1INCH  2.136479e+01  2.206648e+01  3.928790e+05  3.934384e+05  \
# 1     1INCH  1.397492e+06  1.412508e+06  2.624126e+06  2.602407e+06
# 2     1INCH  5.347857e+05  5.218062e+05  2.716118e+03  2.847210e+03
# 3     1INCH  4.089395e+05  3.941708e+05  4.492017e+02  4.476289e+02
# 4     1INCH  1.542793e+05  1.542793e+05  4.063491e+03  4.013937e+03
# ...     ...           ...           ...           ...           ...
# 1980    ZRX  9.244504e+02  9.250840e+02  5.855079e+07  5.855064e+07
# 1981    ZRX  3.590938e+01  3.590938e+01  2.991312e+03  2.991312e+03
# 1982    ZRX  3.953760e-04  4.278530e-04  2.766628e+07  2.485412e+07
# 1983    ZRX  1.412060e-04  1.412060e-04  1.479480e+07  1.373156e+07
# 1984    ZRX  5.009135e+08  5.194931e+08  5.087781e+07  5.095122e+07
#
#         18/09/2021    19/09/2021    20/09/2021    21/09/2021    22/09/2021
# ...

# %%
j=df3_A['Token'].unique()
j
# Out:
# array(['1INCH', 'AAVE', 'ABX', 'ACPT', 'ADA', 'AGA', 'AGAR', 'AID',
#        'AIRT', 'AKITA', 'AKRO', 'ALCX', 'ALEPH', 'ALI', 'ALICE', 'ALPA',
#        'ALPACA', 'ALPHA', 'ALU', 'AMIS', 'AMN', 'AMP', 'AMPL', 'AMWMATIC',
#        'ANKR', 'ANY', 'API3', 'ARCONA', 'ARGON', 'ARMOR', 'ARNXM', 'ARPA',
#        'ASS', 'ATRI', 'AUDIO', 'AURORA', 'AUTO', 'AVE', 'AXS', 'BABYCAKE',
#        'BADGER', 'BAKE', 'BAL', 'BAN', 'BANANA', 'BAND', 'BAO', 'BARMY',
#        'BAT', 'BBADGER', 'BBANK', 'BBK', 'BBKFI', 'BBO', 'BBQ', 'BBTC',
#        'BCH', 'BCUBE', 'BDIGG', 'BDO', 'BELT', 'BERRY', 'BEZOGE', 'BHC',
#        'BIFI', 'BITE', 'BLK', 'BLP', 'BMI', 'BMON', 'BNFY', 'BNT', 'BOG',
#        'BOLT', 'BOND', 'BONE', 'BOR', 'BORING', 'BPRO', 'BREW', 'BRICK',
#        'BRTR', 'BRY', 'BSCX', 'BSHIBA', 'BTCB', 'BUILD', 'BUNI', 'BURGER',
#        'BUSD', 'BZRX', 'CAKE', 'CAT', 'CBD', 'CBIX-P', 'CCAKE', 'CEEK',
#        'CEL', 'CFI', 'CGG', 'CGT', 'CHI', 'CHZ', 'CID', 'CNT', 'COMP',
# ...

# %%
token_dfs = {}
for token_name in df3_A['Token'].unique():

    # select all rows for the current token name and store in a dataframe
    token_df = df3_A[df3_A['Token'] == token_name]

    # add the dataframe to the dictionary using the token name as the key
    token_dfs[token_name] = token_df

# %%
df3_A[df3_A["Token"]=='ZLOT']
# Out:
#      Token     14/09/2021     15/09/2021     16/09/2021     17/09/2021
# 1957  ZLOT  270241.905800  266187.541300   81607.507020   84806.573570  \
# 1958  ZLOT  130213.617200  132184.072900  289060.452800  270694.057700
# 1959  ZLOT   44258.782360   44282.146380       8.715093       8.715093
# 1960  ZLOT   42651.293780   42011.408220   48027.556940   50027.711570
# 1961  ZLOT   19266.205560   22396.963960    3197.500158    8843.439032
# 1962  ZLOT    1636.156650    1467.089681     344.389273     344.389273
# 1963  ZLOT       8.715093       8.715093    4202.393998    4210.127512
# 1964  ZLOT       6.270963       6.270963    1467.089681    3705.754512
#
#          18/09/2021     19/09/2021     20/09/2021     21/09/2021
# 1957   76783.518480   78144.928380   82939.701690   77942.891740  \
# 1958  248307.219900  256435.342900  244749.432200  213210.722400
# 1959       8.808131       8.808131       8.808131       8.808131
# 1960   45294.881690   46097.982430   48926.436950   26681.171590
# ...

# %% [markdown]
# ## Minimum and Maximum price of each token

# %%
df2.groupby('Token').max()
# Out:
#          14/09/2021    15/09/2021    16/09/2021    17/09/2021    18/09/2021
# Token
# 1INCH  1.397492e+06  1.412508e+06  2.624126e+06  2.602407e+06  2.602749e+06  \
# AAVE   2.981762e+06  3.040122e+06  4.659910e+05  4.547623e+05  4.221213e+05
# ABX    7.222393e+03  7.385191e+03  5.109708e+05  5.018564e+05  4.870593e+05
# ACPT   6.489054e+04  6.904028e+04  3.058056e+04  3.010761e+04  2.836882e+04
# ADA    2.523742e+06  2.492814e+06  2.479841e+06  2.529258e+06  2.528271e+06
# ...             ...           ...           ...           ...           ...
# ZCN    1.612095e+08  1.687415e+08  3.328514e+05  3.257190e+05  3.193561e+05
# ZEE    8.782511e+05  8.797337e+05  6.550080e+05  6.659472e+05  6.145182e+05
# ZIPT   6.117355e+05  6.335142e+05  4.110782e+05  3.945669e+05  3.772385e+05
# ZLOT   2.702419e+05  2.661875e+05  2.890605e+05  2.706941e+05  2.483072e+05
# ZRX    5.009135e+08  5.194931e+08  5.855079e+07  5.863496e+07  5.916576e+07
#
# ...

# %%
miximum_value_locked_daily=df2.groupby('Token').max()
miximum_value_locked_daily.to_csv('miximum_value_locked_daily.csv')

# %%
df2.groupby('Token').min()
# Out:
#          14/09/2021    15/09/2021    16/09/2021    17/09/2021    18/09/2021
# Token
# 1INCH  2.136479e+01  2.206648e+01    233.183518    247.939132    234.109947  \
# AAVE   0.000000e+00  0.000000e+00      0.000000      0.000000      0.000000
# ABX    1.286875e+01  1.292676e+01      0.222835      0.222834      0.222832
# ACPT   6.489054e+04  6.904028e+04  30580.564530  30107.612490  28368.816510
# ADA    5.090000e-09  5.760000e-09      0.001208      0.001191      0.001238
# ...             ...           ...           ...           ...           ...
# ZCN    2.400481e+06  2.400481e+06   3595.551742   3691.133307   3641.619807
# ZEE    5.590748e+01  5.590748e+01     55.907480     55.907480     55.907480
# ZIPT   1.449339e+04  1.496192e+04  30262.788090  30262.788090  30262.788090
# ZLOT   6.270963e+00  6.270963e+00      8.715093      8.715093      8.808131
# ZRX    1.412060e-04  1.412060e-04     35.909384     35.909384     35.909384
#
# ...

# %%
minimum_value_locked_daily=df2.groupby('Token').min()
minimum_value_locked_daily.to_csv('minimum_value_locked_daily.csv')
